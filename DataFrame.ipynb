# %%
# !pip

# %%
#Creating a DataFrame from a Dictionary

import pandas as pd

# Dictionary with lists
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}

# Creating DataFrame
df = pd.DataFrame(data)

print("DataFrame from a dictionary:")
print(df)
# Out:
# DataFrame from a dictionary:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
#Creating a DataFrame from a List of Dictionaries
# List of dictionaries
data = [
    {'Name': 'Alice', 'Age': 25, 'City': 'New York'},
    {'Name': 'Bob', 'Age': 30, 'City': 'Los Angeles'},
    {'Name': 'Charlie', 'Age': 35, 'City': 'Chicago'},
    {'Name': 'David', 'Age': 40, 'City': 'Houston'}
]

# Creating DataFrame
df = pd.DataFrame(data)

print("\nDataFrame from a list of dictionaries:")
print(df)
# Out:
# DataFrame from a list of dictionaries:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
#Creating a DataFrame from a List of Lists


# List of lists
data = [
    ['Alice', 25, 'New York'],
    ['Bob', 30, 'Los Angeles'],
    ['Charlie', 35, 'Chicago'],
    ['David', 40, 'Houston']
]

# Creating DataFrame with specified column names
df = pd.DataFrame(data, columns=['Name', 'Age', 'City'])

print("\nDataFrame from a list of lists:")
print(df)
# Out:
# DataFrame from a list of lists:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
#Creating a DataFrame from NumPy Arrays

import numpy as np

# NumPy arrays
names = np.array(['Alice', 'Bob', 'Charlie', 'David'])
ages = np.array([25, 30, 35, 40])
cities = np.array(['New York', 'Los Angeles', 'Chicago', 'Houston'])

# Creating DataFrame
df = pd.DataFrame({
    'Name': names,
    'Age': ages,
    'City': cities
})

print("\nDataFrame from NumPy arrays:")
print(df)
# Out:
# DataFrame from NumPy arrays:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
#Creating a DataFrame with Random Data

# Creating a DataFrame with random data
random_data = np.random.rand(4, 3)  # 4 rows, 3 columns
df = pd.DataFrame(random_data, columns=['Column1', 'Column2', 'Column3'])

print("\nDataFrame with random data:")
print(df)
# Out:
# DataFrame with random data:
#     Column1   Column2   Column3
# 0  0.499715  0.325258  0.751568
# 1  0.668425  0.622361  0.222001
# 2  0.149078  0.940302  0.527260
# 3  0.699544  0.060811  0.553244

# %%
Creating a DataFrame from a CSV File

# Creating a DataFrame from a CSV file
# Assuming 'data.csv' exists with appropriate content
df = pd.read_csv('data.csv')

print("\nDataFrame from a CSV file:")
print(df)

# %%
#Creating a DataFrame with DateTime Index

# Creating a DataFrame with DateTime index
dates = pd.date_range('20230101', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

print("\nDataFrame with DateTime index:")
print(df)
# Out:
# DataFrame with DateTime index:
#                    A         B         C         D
# 2023-01-01 -0.846479  0.079260 -0.787729 -0.573876
# 2023-01-02  0.225716  1.908224  0.799447 -0.051620
# 2023-01-03  0.570389  1.963697 -1.546984 -0.367788
# 2023-01-04  0.417480  0.361266 -0.352679  0.063839
# 2023-01-05 -0.166413  0.118417 -0.616430  0.145235
# 2023-01-06  0.457496  0.284665 -2.386056 -0.629158
